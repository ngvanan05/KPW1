# %%
import re
import os
from bs4 import BeautifulSoup
from underthesea import word_tokenize

# %%
stopword_path = r"D:\\10\\Cau2\\Data\\vietnamese-stopwords.txt" 
with open(stopword_path, "r", encoding="utf-8") as f:
    stopwords = set(line.strip() for line in f if line.strip())
    
    print(stopwords)
    
def preprocess_text(text: str): 
    #Loại bỏ thẻ HTML 
    text = BeautifulSoup(text, "html.parser").get_text()

    #Chuyển chữ thường
    text = text.lower()

    # Xóa URL và html
    text = re.sub(r"http\S+|www\S+|https\S+", " ", text)

    # Xóa dấu câu, số và ký tự đặc biệt 
    text = re.sub(r"[^a-zA-ZÀ-ỹ\s]", " ", text)

    # Tách từ tiếng Việt 
    tokens = word_tokenize(text, format="text").split()

    # Loại bỏ stopword 
    tokens = [w for w in tokens if w not in stopwords and len(w) >= 1]

    # Ghép lại thành chuỗi 
    return " ".join(tokens)


input = r"D:\\10\\Cau2\\Data\\Data_Cau2"
output = r"D:\\10\\Cau2\\Data\\Preprocessing"


index = 1
for file in os.listdir(input):
    if file.endswith(".txt"):
        path_in = os.path.join(input, file)
        with open(path_in, "r", encoding="utf-8") as f:
            content = f.read()
        
        # Tiền xử lý
        result = preprocess_text(content)
        
        # Tạo tên file mới
        file_out = f"10_Pre{index}.txt"
        path_out = os.path.join(output, file_out)
        
        # Ghi ra thư mục đích
        with open(path_out, "w", encoding="utf-8") as out:
            out.write(result)
        print("Xuất File:  ", file_out)
        index += 1
# Out:
# {'nước quả', 'đã', 'tự tạo', 'nhỏ', 'nhất mực', 'phỏng tính', 'riêng', 'sau hết', 'theo', 'thuộc cách', 'nhà khó', 'nói riêng', 'thái quá', 'đó đây', 'nóc', 'qua', 'xem ra', 'ba cùng', 'rồi sau', 'khỏi nói', 'nặng về', 'sa sả', 'cho', 'dạ bán', 'giá trị thực tế', 'ngay lúc này', 'chợt nhìn', 'lần lần', 'hay hay', 'giờ', 'vậy thì', 'bỏ riêng', 'cũng', 'ngày nào', 'tay', 'nghĩ tới', 'của', 'trong số', 'mọi lúc', 'bà', 'khó thấy', 'hiểu', 'mỗi ngày', 'từ tính', 'giờ đây', 'bằng như', 'chứ gì', 'bông', 'cụ thể như', 'tránh ra', 'lần', 'sau', 'rứa', 'ngay lập tức', 'từng nhà', 'vì sao', 'lên đến', 'dễ sử dụng', 'áng như', 'những khi', 'ý da', 'tốt mối', 'ăn chung', 'bằng nấy', 'nghĩ', 'chui cha', 'ngay khi', 'vượt', 'so với', 'lấy lý do', 'dù rằng', 'nhờ', 'ra lời', 'công nhiên', 'đã thế', 'nguồn', 'tìm cách', 'mới hay', 'ra ngôi', 'trước hết', 'bởi thế', 'cái đã', 'thanh điểm', 'amen', 'cần số', 'nói với', 'lấy thế', 'để phần', 'đến khi', 'mọi sự', 'tất cả bao nhiêu', 'phần', 'chung quy', 'do đó', 'tuy thế', 'đầy', 'không kể', 'cuối điểm', 'bất kỳ', 'phè', 'xệp', 'khác nhau', 'có khi', 'sử dụng', 'không biết', 'phương chi', 'á', 'khi nào', 'thật thà', 'gần hết', 'chứ lại', 'nước lên', 'chắc vào', 'tên họ', 'xuất kỳ bất ý', 'thanh', 'quay bước', 'đến nơi', 'ngày ngày', 'bộ thuộc', 'tha hồ chơi', 'từ căn', 'không có', 'gần bên', 'quá nhiều', 'chưa bao giờ', 'lại thôi', 'chị', 'làm đúng', 'có thế', 'những muốn', 'bên bị', 'đều nhau', 'loại', 'quả', 'rồi đây', 'nên chăng', 'ăn hỏi', 'tuy đã', 'đáo để', 'chẳng phải', 'thế mà', 'gây', 'quá lời', 'nào là', 'phải khi', 'nói đến', 'tại đó', 'vung tán tàn', 'ngoải', 'khác thường', 'thêm', 'nhất là', 'bấy nhiêu', 'chùn chùn', 'cá nhân', 'trừ phi', 'hỏi xin', 'nói trước', 'trước đó', 'căn tính', 'chú dẫn', 'nặng mình', 'cứ như', 'thuộc lại', 'yêu cầu', 'hoặc là', 'sắp đặt', 'trước', 'vấn đề', 'để được', 'hay là', 'đều đều', 'phù hợp', 'thốt nói', 'chịu ăn', 'mang mang', 'cây nước', 'ở nhờ', 'xăm xắm', 'khá tốt', 'bèn', 'khi khác', 'cùng chung', 'anh ấy', 'chung nhau', 'thục mạng', 'mợ', 'cơ', 'thì giờ', 'khác', 'cụ thể là', 'lúc lâu', 'cô mình', 'cái họ', 'từ khi', 'còn như', 'xiết bao', 'ăn tay', 'hết ráo', 'nói thêm', 'hỏi xem', 'quay đi', 'đúng ra', 'chung ái', 'riêng từng', 'mọi việc', 'phót', 'qua đi', 'biết bao nhiêu', 'sớm ngày', 'nào cũng', 'từng giờ', 'chứ sao', 'số là', 'đại để', 'bị vì', 'em em', 'tanh', 'thành ra', 'bản riêng', 'mất', 'số', 'thím', 'đúng với', 'đến gần', 'chắc ăn', 'gần như', 'tại lòng', 'đó', 'đến lúc', 'lên xuống', 'thiếu', 'bán cấp', 'ngay khi đến', 'biết mấy', 'để giống', 'cao lâu', 'đâu đâu', 'không những', 'khó tránh', 'chăng', 'xăm xăm', 'làm mất', 'ngay tức khắc', 'cho hay', 'thỏm', 'tạo nên', 'làm tôi', 'ừ ào', 'bất tử', 'của tin', 'thay đổi tình trạng', 'với', 'lại còn', 'này', 'hết ý', 'nhìn theo', 'chậc', 'làm thế nào', 'ngọn', 'chuyển', 'cấp trực tiếp', 'thế chuẩn bị', 'tránh', 'làm tại', 'giữ ý', 'văng tê', 'đủ điểm', 'nói', 'khỏi', 'tuốt tuồn tuột', 'biết chừng nào', 'lớn', 'các', 'gây giống', 'dù', 'trước đây', 'cần gì', 'dễ', 'bất chợt', 'bằng nào', 'à ơi', 'việc', 'đây', 'ắt hẳn', 'sẽ hay', 'lượng từ', 'tất thảy', 'tiếp tục', 'bởi nhưng', 'bất thình lình', 'không bán', 'ái dà', 'ăn hết', 'cách nhau', 'và', 'bằng', 'cơ hồ', 'cho rồi', 'tiện thể', 'không được', 'bỗng chốc', 'bộ', 'có tháng', 'rón rén', 'rồi ra', 'trước sau', 'quá giờ', 'xa cách', 'làm sao', 'tính từ', 'rằng là', 'trệu trạo', 'có họ', 'thế thường', 'ăn', 'thanh chuyển', 'ráo trọi', 'thộc', 'ào vào', 'mọi giờ', 'quả thế', 'hết cả', 'ngày ấy', 'thường xuất hiện', 'chăn chắn', 'ngõ hầu', 'nhưng', 'tăng giảm', 'cực lực', 'phải lời', 'lấy', 'lên mạnh', 'nhận được', 'nghe trực tiếp', 'phía trong', 'có người', 'chắc người', 'ôi thôi', 'từng', 'bỏ', 'trong', 'để', 'chầm chập', 'coi mòi', 'giảm thấp', 'chọn', 'để mà', 'ứ ừ', 'ăn cuộc', 'trực tiếp làm', 'lâu ngày', 'tha hồ ăn', 'cứ điểm', 'nhớ ra', 'không phải không', 'chính là', 'có ngày', 'thế thế', 'lúc khác', 'đến xem', 'ờ', 'con con', 'l ...
# Xuất File:   10_Pre1.txt
# Xuất File:   10_Pre2.txt
# Xuất File:   10_Pre3.txt
# Xuất File:   10_Pre4.txt
# Xuất File:   10_Pre5.txt
# Xuất File:   10_Pre6.txt
# Xuất File:   10_Pre7.txt
# Xuất File:   10_Pre8.txt
# Xuất File:   10_Pre9.txt
# Xuất File:   10_Pre10.txt
